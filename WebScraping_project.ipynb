# %%
import requests

# %%
url = "https://www.geeksforgeeks.org/"
response = requests.get(url)

# %%
print(response.status_code)
print(response.text[:500])
# Out:
# 200
# <!DOCTYPE html><html lang="en"><head><script type="application/ld+json">{"@context":"http://schema.org","@type":"Organization","name":"GeeksforGeeks","url":"https://www.geeksforgeeks.org/","logo":"https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200817185016/gfg_complete_logo_2x-min.png","description":"Your All-in-One Learning Portal. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company i

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
title = soup.find("h1")
print(title.text.strip())
# Out:
# Need help withCareer Guidance?

# %%
soup.h1.text
# Out:
# 'Need help withCareer Guidance?'

# %%
soup.h2.text
# Out:
# 'Courses'

# %%
products = soup.find_all("div", class_="product")

data = []

for product in products:
    name = product.find("h2").text.strip()
    price = product.find("span", class_="price").text.strip()

    data.append({
        "Product": name,
        "Price": price
    })

# %%
import pandas as pd

df = pd.DataFrame(data)

print(df.head())

df.to_csv("products.csv", index=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
